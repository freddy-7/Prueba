# %% [markdown]
# <a href="https://colab.research.google.com/github/freddy-7/Prueba/blob/main/Regresi%C3%B3n_Lineal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Cargar archivo csv desde equipo
#from google.colab import files
#files.upload()

# %%
#df= pd.read_csv("car_crashes.csv")
#df

# %%
#Cargar archivo csv desde seaborn
df=sns.load_dataset(name='car_crashes')
df.head(5)

# %%
#Imprimimos el scatter plot entre la variable dependiente e independiente para 
#observar el comportamiento en su dispersión 
from turtle import color


sns.scatterplot(x='alcohol', y='total', color="blue", data=df)
#sns.scatterplot(X='speeding', y='total', color="red", data=df)
# Out:
# <Axes: xlabel='alcohol', ylabel='total'>
